# %%
import pandas as pd

validacoes = { 'cidade': ['andradina', 'ouro preto'],
              'validacoes' : ([1, 2, 3],[ 4, 5])}

validacoes_df = pd.DataFrame(validacoes)

display(validacoes_df)
# Out:
#        cidade validacoes
# 0   andradina  [1, 2, 3]
# 1  ouro preto     [4, 5]

# %%
pip install openpyxl
# Out:
# 1841.38s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting openpyxl
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import openpyxl 

df = pd.read_excel("validacoes.xlsx")
display(df)
# Out:
#             Ouro Preto                             06, 12, 13, 14, 21, 35  \
# 0        Alta Floresta                                                 06
# 1            Andradina                                             06, 42
# 2            Andradina                                       PROCESSO 111
# 3              Colider  ERRO NO PROCESSO 67: Existe(m) campo(s) obriga...
# 4              Colider                                             06, 18
# 5             Comodoro                                                 42
# 6               Cuiabá                         06, 07, 12, 13, 14, 21, 42
# 7               Cuiabá                                       PROCESSO 111
# 8               Itapoá                                                 06
# 9             Mirassol                                                 44
# 10      Miguel Pereira                                             06, 35
# 11           Paranaguá                             06, 12, 13, 14, 21, 42
# 12           Paranaguá                                       PROCESSO 111
# 13     Paty do Alferes                                                 35
# 14      Rio de Janeiro                     12, 13, 14, 35, 42, 46, 47, 51
# 15      Rio de Janeiro                                       PROCESSO 111
# 16       Verde Alagoas                                             06, 10
# 17           Joinville  ERRO NO PROCESSO 67: Lançamento de parcelament...
# 18           Joinville                 06, 08, 10, 11, 12, 13, 14, 29, 35
# 19             Atibaia  01, 05, 06, 07, 08, 10, 11, 12, 13, 14, 21, 29...
# 20      Angra dos Reis  ERRO NO PROCESSO 67: Não existe mais saldo pen...
# 21      Angra dos Reis                                 05, 08, 12, 13, 14
# 22             Araricá                                     05, 12, 13, 14
# 23             Cáceres                                 05, 12, 13, 14, 35
# 24             Conchal  ERRO NO PROCESSO 67: Não foi possível realizar...
# 25             Conchal                                     10, 11, 33, 35
# 26               Guará  05, 06, 07, 08, 10, 11, 12, 13, 14, 21, 29, 30...
# 27             Itapema                                                 06
# 28             Jacundá                         08, 10, 12, 13, 14, 21, 29
# 29      Jaraguá do Sul  ERRO NO PROCESSO 67: Não foi possível realizar...
# 30      Jaraguá do Sul                                     06, 10, 11, 21
# 31  Lucas do Rio Verde  ERRO NO PROCESSO 67: gravarLancamentoBase.erro...
# 32  Lucas do Rio Verde                                                 07
# 33   Mineiros do Tietê  ERRO NO PROCESSO 67: Ocorreu um erro no sistem...
# 34   Mineiros do Tietê                                                 35
# 35     Morro da Fumaça  ERRO NO PROCESSO 67: Existe uma diferença no d...
# 36     Morro da Fumaça                             05, 10, 11, 12, 13, 14
# 37          Nova Mutum                             07, 08, 12, 13, 14, 35
# 38            Orlândia  ERRO NO PROCESSO 67: Não existe mais saldo pen...
# 39            Orlândia  05, 06, 07, 08, 10, 12, 13, 14, 18, 21, 29, 30...
# 40           Penápolis                                                 29
# 41    São Bento do Sul  ERRO NO PROCESSO 67: Não existe mais saldo pen...
# 42    São Bento do Sul                             05, 06, 12, 13, 14, 29
# 43         São Gabriel                                     05, 12, 13, 14
# 44         São Ludgero                                                 07
# 45             Tapurah                                                 21
#
#     Unnamed: 2  Unnamed: 3                               Unnamed: 4
# 0          NaN         NaN                                      NaN
# 1          NaN         NaN                                      NaN
# 2          NaN         NaN                                      NaN
# 3          NaN         NaN  Último Lançamento Realizado: 07/11/2023
# 4          NaN         NaN                                      NaN
# 5          NaN         NaN                                      NaN
# 6          NaN         NaN                                      NaN
# 7          NaN         NaN                                      NaN
# 8          NaN         NaN                                      NaN
# 9          NaN         NaN                                      NaN
# 10         NaN         NaN                                      NaN
# 11         NaN         NaN                                      NaN
# 12         NaN         NaN                                      NaN
# 13         NaN         NaN                                      NaN
# 14         NaN         NaN                                      NaN
# 15         NaN         NaN                                      NaN
# 16         NaN         NaN                                      NaN
# 17         NaN         NaN  Último Lançamento Realizado: 07/11/2023
# 18         NaN         NaN                                      NaN
# 19         NaN         NaN                                      NaN
# 20         NaN         NaN  Último Lançamento Realizado: 09/01/2022
# 21         NaN         NaN                                      NaN
# 22         NaN         NaN                                      NaN
# 23         NaN         NaN                                      NaN
# 24         NaN         NaN  Último Lançamento Realizado: 15/11/2023
# 25         NaN         NaN                                      NaN
# 26         NaN         NaN                                      NaN
# 27         NaN         NaN                                      NaN
# 28         NaN         NaN                                      NaN
# 29         NaN         NaN  Último Lançamento Realizado: 08/01/2023
# 30         NaN         NaN                                      NaN
# 31         NaN         NaN  Último Lançamento Realizado: 06/11/2023
# 32         NaN         NaN                                      NaN
# 33         NaN         NaN  Último Lançamento Realizado: 13/11/2023
# 34         NaN         NaN                                      NaN
# 35         NaN         NaN  Último Lançamento Realizado: 16/11/2023
# 36         NaN         NaN                                      NaN
# 37         NaN         NaN                                      NaN
# 38         NaN         NaN  Último Lançamento Realizado: 25/05/2023
# 39         NaN         NaN                                      NaN
# 40         NaN         NaN                                      NaN
# 41         NaN         NaN  Último Lançamento Realizado: 13/11/2023
# 42         NaN         NaN                                      NaN
# 43         NaN         NaN                                      NaN
# 44         NaN         NaN                                      NaN
# 45         NaN         NaN                                      NaN
